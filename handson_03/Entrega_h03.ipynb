% %% [markdown]
% # Entrega do handson 03

% %% [markdown]
% ## D01: comparado sinais sonoros em frequência (Flauta)

% %%
close all;clc;clear all;                                          % Limpa variáveis e fecha todos os gráficos
soundFile = ['./Flauta.wav'];             % Especifica do local e nome do arquivo de áudio
[vtSom, dFa] = audioread(soundFile);                              % Abre arquivo de áudio de um arquivo
% vtSom: amplitude das amostras de som
% dFa: frequência de amostrasgem do som (amostragem no tempo)
dta = 1/dFa;                                                      % Tempo entre amostras
dTFinal = (length(vtSom)-1)*dta;                                  % Tempo da última amostra do sinal de áudio
vtTSom = 0:dta:dTFinal;                                            % Eixo temporal do arquivo de áudio
subplot(2,1,1)
plot(vtTSom,vtSom);                                               % Plota gráfico do áudio
set(gcf,'color',[1 1 1]);                                         % Configura área da figura
set(gca,'FontWeight','bold','FontSize',12);                       % Configura área do gráfico
title(['Sinal de Áudio']);                                        % Configura título do gráfico
ylabel('Amplitude');                                              % Configura eixo X do gráfico
xlabel('Tempo (s)');                                        % Configura eixo Y do gráfico
axis([ 0 0.022 -0.5 0.5]);
%p = audioplayer(vtSom, 1*dFa);                                    % Reproduzir arquivo de áudio
%play(p);
%---------------------------------------------------------------------------
%% Geração do sinal cosenoidal
fsampling = dFa;                                               % Taxa de amostragem
tf = dta;                                                     % Tempo entre amostras
t = 0 : (1/fsampling) : tf;                                   % Eixo do tempo

%% Visualizando a amplitude do espectro com um tamanho arbitrário para a fft
lfft = 2^nextpow2(length(vtSom));                                       % Tamanho da FFT  
% Construção do single-sided amplitude spectrum.
yfft = fft(vtSom,lfft)/lfft;                                      % Cálculo da FFT via função do Matlab
freq1 = [0 : fsampling/lfft : fsampling/2 - fsampling/lfft];  % Definição do eixo das frequências unilateral
yfftuni = yfft(1:lfft/2);
% Coleta da FFT unilateral
 
subplot(2,1,2)
plot(freq1,abs(yfftuni));                                     % Plotagem do espectro unilateral M(f)               
title('Amplitude unilateral do Espectro de m(t)');            % Configuração do título do gráfico 
xlabel('Frequencia (kHz)');                                   % Configuração do eixo x do gráfico 
ylabel('|M(f)|');                                             % Configuração do eixo y do gráfico  
grid on;                                                      % Adiona o grid 
axis([ 0 3000 0 0.06]);

% %% [markdown]
% ## D01: comparado sinais sonoros em frequência (Violino)

% %%
close all;clc;clear all;                                          % Limpa variáveis e fecha todos os gráficos
soundFile = ['./Violino.wav'];             % Especifica do local e nome do arquivo de áudio
[vtSom, dFa] = audioread(soundFile);                              % Abre arquivo de áudio de um arquivo
% vtSom: amplitude das amostras de som
% dFa: frequência de amostrasgem do som (amostragem no tempo)
dta = 1/dFa;                                                      % Tempo entre amostras
dTFinal = (length(vtSom)-1)*dta;                                  % Tempo da última amostra do sinal de áudio
vtTSom = 0:dta:dTFinal;                                            % Eixo temporal do arquivo de áudio
subplot(2,1,1)
plot(vtTSom,vtSom);                                               % Plota gráfico do áudio
set(gcf,'color',[1 1 1]);                                         % Configura área da figura
set(gca,'FontWeight','bold','FontSize',12);                       % Configura área do gráfico
title(['Sinal de Áudio']);                                        % Configura título do gráfico
ylabel('Amplitude');                                              % Configura eixo X do gráfico
xlabel('Tempo (s)');                                        % Configura eixo Y do gráfico
axis([ 0 0.022 -0.5 0.5]);
%p = audioplayer(vtSom, 1*dFa);                                    % Reproduzir arquivo de áudio
%play(p);
%---------------------------------------------------------------------------
%% Geração do sinal cosenoidal
fsampling = dFa;                                               % Taxa de amostragem
tf = dta;                                                     % Tempo entre amostras
t = 0 : (1/fsampling) : tf;                                   % Eixo do tempo

%% Visualizando a amplitude do espectro com um tamanho arbitrário para a fft
lfft = 2^nextpow2(length(vtSom));                                       % Tamanho da FFT  
% Construção do single-sided amplitude spectrum.
yfft = fft(vtSom,lfft)/lfft;                                      % Cálculo da FFT via função do Matlab
freq1 = [0 : fsampling/lfft : fsampling/2 - fsampling/lfft];  % Definição do eixo das frequências unilateral
yfftuni = yfft(1:lfft/2);
% Coleta da FFT unilateral
 
subplot(2,1,2)
plot(freq1,abs(yfftuni));                                     % Plotagem do espectro unilateral M(f)
title('Amplitude unilateral do Espectro de m(t)');            % Configuração do título do gráfico 
xlabel('Frequencia (kHz)');                                   % Configuração do eixo x do gráfico 
ylabel('|M(f)|');                                             % Configuração do eixo y do gráfico  
grid on;                                                      % Adiona o grid 
axis([ 0 3000 0 0.06]);

% %% [markdown]
% ## Análise comparativa entre os dois sinais
%
% **No tempo:** Pode-se perceber que ambos os sinais sonoros (Flauta e Violino) possuem o mesmo período. No espaço exibido há 10 ciclos repetidos em cada sinal. A forma de onda em cada ciclo é diferente e é isso que causa a diferença entre os timbres quando reproduzimos cada sinal, porém é possivel determinar uma semelhança entre ambos.
%
% **Na frequência:** Pode-se perceber que, em ambos os sinais, as frequências de maior contribuição são próxima a faixa de 440hz e seus múltiplos. Pode-se concluir a partir disso que ambos os instrumentos representados nos sinais tocam uma nota Lá. A diferença na contribuição de cada frequência demonstra mais harmônicos no Violino do que na Flauta e isso justifica o que foi constatado no tempo. Como o sinal está sendo normalizado as componentes em frequências do sinal do Violino são menores em intensidade já que são em maior quantidade.
%
% **Conclusão:** A simulação se parece bastante com esperado. O som dos instrumentos foi bem representado nos arquivos. Podemos comparar os resultados com uma amostragem feita com os instrumentos reais:
% ![Fig_instrumentos](https://www.researchgate.net/profile/Konstantinos_Fysarakis/publication/283516305/figure/download/fig1/AS:297226430631938@1447875711305/Fig-3-Top-Flute-playing-Note-A4-at-440-Hz-Middle-Violin-playing-the-same-note.png)

% %% [markdown]
% # Versão em Python
